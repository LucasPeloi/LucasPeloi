# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasPeloi/LucasPeloi/blob/main/OlaMundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Esse é meu primeiro programa no google colab

# %%
print("Olá Mundo!")
# Out:
# Olá Mundo!

# %%
print("Esse é meu primeiro programa em phyton")
# Out:
# Esse é meu primeiro programa em phyton

# %% [markdown]
# #Operadores Aritmédicos

# %% [markdown]
# Soma

# %%
4+5
# Out:
# 9

# %%
2.7+2.5
# Out:
# 5.2

# %% [markdown]
# Substração

# %%
6-2
# Out:
# 4

# %%
2.7-2.2
# Out:
# 0.5

# %% [markdown]
# Multiplicação

# %%
5*5
# Out:
# 25

# %% [markdown]
# Divisão

# %%
10/2
# Out:
# 5.0

# %%
10//3 #retorna apenas o inteiro
# Out:
# 3

# %%
10%3 #resto da divisão
# Out:
# 1

# %% [markdown]
# #Operadores lógicos #True or false
