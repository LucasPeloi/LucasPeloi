# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasPeloi/LucasPeloi/blob/main/PhytonBasico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Esse é meu primeiro programa no google colab

# %%
print("Olá Mundo!")
# Out:
# Olá Mundo!

# %%
print("Esse é meu primeiro programa em phyton")
# Out:
# Esse é meu primeiro programa em phyton

# %% [markdown]
# #Operadores Aritmédicos

# %% [markdown]
# Soma

# %%
4+5
# Out:
# 9

# %%
2.7+2.5
# Out:
# 5.2

# %% [markdown]
# Substração

# %%
6-2
# Out:
# 4

# %%
2.7-2.2
# Out:
# 0.5

# %% [markdown]
# Multiplicação

# %%
5*5
# Out:
# 25

# %% [markdown]
# Divisão

# %%
10/2
# Out:
# 5.0

# %%
10//3 #retorna apenas o inteiro
# Out:
# 3

# %%
10%3 #resto da divisão
# Out:
# 1

# %% [markdown]
# #Operadores lógicos #True or false

# %% [markdown]
# Maior que(>), Maior igual(>=), Menor que(<), Menor Igual(<=), Igualdade(==), Diferença (!=)

# %%
8>4
# Out:
# True

# %%
10<3
# Out:
# False

# %%
10<=10
# Out:
# True

# %%
10>=10
# Out:
# True

# %%
20 == 21
# Out:
# False

# %%
20 != 21
# Out:
# True

# %% [markdown]
# #Funções Built-in

# %% [markdown]
# abs() #retorna o valor absoluto

# %%
abs(-10)
# Out:
# 10

# %% [markdown]
# min() # retorna o valor mínimo de uma sequencia

# %%
menorPreco=min(6,7,3,5,8,10,2)
print(menorPreco)
# Out:
# 2

# %% [markdown]
# max() # Retonar o valor máximo de uma sequencia

# %%
maiorPreco=max(6,7,3,5,8,10,2)
print(maiorPreco)
# Out:
# 10

# %% [markdown]
# sum() #retornar a soma de uma sequencia

# %%
somaTotal=sum([1,2,3,4,5,6,7,8,9])
print(somaTotal)
# Out:
# 45

# %% [markdown]
# pow() #exponenciação

# %%
pow(2,3)
# Out:
# 8

# %% [markdown]
# print() #saida

# %%
print("Olá Mundo!")
# Out:
# Olá Mundo!

# %% [markdown]
# input() #entrada

# %%
nome = input("Qual é o seu nome? ")
print("Olá", nome)
# Out:
# Qual é o seu nome? lucas peloi
# Olá lucas peloi

# %% [markdown]
# help() #mostra funcionalidade de uma função

# %%
help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of google.colab._kernel.Kernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.
